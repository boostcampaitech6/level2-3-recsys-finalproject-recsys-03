# %%
import pandas as pd
import json

# %% [markdown]
# ### load data

# %%
chunk_size = 1000000
chunks = []
df_dtype = {'user_id': 'int32', 'track_id': 'int32', 'count': 'int16'}
for i, chunk in enumerate(pd.read_csv('./data/listening-counts.tsv', sep='\t', dtype=df_dtype, chunksize=chunk_size)):
    chunks.append(chunk)
listening = pd.concat(chunks, ignore_index=True)
listening
# Out:
#            user_id  track_id  count
# 0            92915  26719936      1
# 1            92915   4271407      1
# 2            92915   4606511      1
# 3            92915   8966085      1
# 4            92915  12290897      1
# ...            ...       ...    ...
# 519293328   119080  44144633      1
# 519293329   119080  45141923      1
# 519293330   119080  46171716      1
# 519293331   119080  46245572      1
# 519293332   119080   4705833      1
#
# [519293333 rows x 3 columns]

# %%
listening_count = listening.groupby('track_id').agg({'user_id': 'count', 'count': 'sum'})
listening_count.columns = ['n_user', 'total_listening']
listening_count
# Out:
#           n_user  total_listening
# track_id
# 0              1                2
# 1              1                1
# 2              1                2
# 3              1                1
# 4              1                6
# ...          ...              ...
# 50813368       1                1
# 50813369       1                1
# 50813370       2                2
# 50813371       1                1
# 50813372       1                1
#
# [50813373 rows x 2 columns]

# %%
df_dtype = {'track_id': 'int32'}
tracks = pd.read_csv('./data/tracks.tsv', sep='\t', dtype=df_dtype, on_bad_lines='skip')
tracks
# Out:
#           track_id       artist_name  \
# 0                0         Mika Miko
# 1                1              Comm
# 2                2          deadmau5
# 3                3  Rasheed Chappell
# 4                4               rck
# ...            ...               ...
# 50723391  50813368        ЗупиниЛося
# 50723392  50813369        ЗупиниЛося
# 50723393  50813370     Lost Cascades
# 50723394  50813371     Lost Cascades
# 50723395  50813372               百合花
#
#                                                  track_name
# 0                                                       NaN
# 1
# 2
# 3
# 4
# ...                                                     ...
# 50723391  🦌 ЗупиниЛося №60. Бійки, стрілянина і табуни д...
# 50723392  🦌 ЗупиниЛося №69. Повний паркувальний бардак н...
# 50723393                 🧝‍♀️ 𝒜 𝒮𝓉𝓇𝒶𝓃𝑔𝑒𝓇 𝒜𝓅𝓅𝓇𝑜𝒶𝒸𝒽𝑒𝓈: '𝒟𝓇𝒶𝓊⻕
# 50723394  🧝♀️ 𝒜 𝒮𝓉𝓇𝒶𝓃𝑔𝑒𝓇 𝒜𝓅𝓅𝓇𝑜𝒶𝒸𝒽𝑒𝓈: '𝒟𝓇𝒶𝓊𝑔𝒽𝓉 𝑜𝒻 𝐵𝓁𝑒𝓈𝓈𝑒𝒹...
# 50723395                                                 𨑨迌
#
# [50723396 rows x 3 columns]

# %%
artists = pd.read_csv('./data/artists.tsv', sep='\t')
artists
# Out:
#          artist_id                                        artist_name
# 0                0                                                NaN
# 1                1                                      ##Horror Inc
# 2                2                                    840
# 8:>;09GC:
# 3                3                         ;5:A0=4@ 20:8= (>: >3)
# 4                4                                      0=40 G5BK@QE
# ...            ...                                                ...
# 5159208    5159575                🦁 ИСТОРИЯ ПАДЕНИЯ КОНОРА МАКГРЕГОРА
# 5159209    5159576                            🦄 Unicorn On Ketamine 🦄
# 5159210    5159577                                       🦄 expedizion
# 5159211    5159578  🦌 ЗупиниЛося №55. ДТП з постраждалими на зустр...
# 5159212    5159579      🦌 ЗупиниЛося №73. Скандали, крики, бійки, газ
#
# [5159213 rows x 2 columns]

# %%
albums = pd.read_csv('./data/albums.tsv', sep='\t', on_bad_lines='skip')
albums
# Out:
# C:\Users\jaegwon\AppData\Local\Temp\ipykernel_21168\1726265373.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   albums = pd.read_csv('./data/albums.tsv', sep='\t', on_bad_lines='skip')
#           album_id                                         album_name  \
# 0                0                                                NaN
# 1                1                                                NaN
# 2                2                                                NaN
# 3                3                                                NaN
# 4                4                                                NaN
# ...            ...                                                ...
# 24208970  24237343  🟠Tvelve Hours of Sunset 🟡2012 🔴1976 1984 1994 ...
# 24208971  24237344  🟣Carte Blanche 🔴1808,1838,1816,1910,1824,1921,...
# 24208972  24237345  🟣Carte Blanche 🔴1808,1838,1816,1910,1824,1921,...
# 24208973  24237346                              🟧Fear of Music 🟩🟦2006
# 24208974  24237347                                     🟧Naked 🟩🟦20106
#
#                           artist_name
# 0                                 NaN
# 1                       ##Horror Inc
# 2                     840
# 8:>;09GC:
# 3
#  DEÿD VIRGIN
#
# 4                                   !
# ...                               ...
# 24208970                David Bedford
# 24208971  Mildred J. Hill, Patty Hill
# 24208972           Witold Lutosławski
# 24208973                Talking Heads
# 24208974                Talking Heads
#
# [24208975 rows x 3 columns]

# %%
tags = []
with open('./data/tags.json', encoding='utf-8') as f:
    for line in f:
        tag = json.loads(line)
        tags.append(tag)
tags = pd.DataFrame(tags)
tags
# Out:
#                                                        _id  \
# 0        {'artist': 'Gotye', 'track': 'Somebody That I ...
# 1        {'artist': 'Adele', 'track': 'Rolling in the D...
# 2        {'artist': 'Imagine Dragons', 'track': 'Radioa...
# 3        {'artist': 'Lana Del Rey', 'track': 'Video Gam...
# 4        {'artist': 'Foster the People', 'track': 'Pump...
# ...                                                    ...
# 2230809   {'artist': 'André Rieu', 'track': 'Espana Cani'}
# 2230810  {'artist': 'Ella Fitzgerald', 'track': 'Make L...
# 2230811  {'artist': 'Shifted Phases', 'track': 'Scatter...
# 2230812  {'artist': 'Alan Parsons Project', 'track': 'E...
# 2230813  {'artist': 'Johnny Tillotson', 'track': 'I'm s...
#
#                                                       tags         i
# 0        {'indie': 100, 'alternative': 79, 'electronic'...  36346257
# 1        {'soul': 100, 'Adele': 95, 'female vocalists':...  33619193
# 2        {'indie': 100, 'rock': 97, 'alternative': 94, ...  32496162
# 3        {'female vocalists': 100, 'pop': 96, 'indie': ...  43433165
# 4        {'indie': 100, 'indie pop': 69, 'catchy': 38, ...  32083560
# ...                                                    ...       ...
# 2230809          {'andre rieu': 100, 'special kikke': 100}  14061289
# 2230810  {'jazz': 100, 'vocal jazz': 50, 'Jazz Vocal Ta...  25494731
# 2230811  {'Electroclash': 100, 'electro': 100, 'techno'...  34506959
# 2230812  {'80s': 100, 'Progressive rock': 97, 'classic ...  14456757
# 2230813                        {'60s': 100, 'oldies': 100}  19888307
#
# [2230814 rows x 3 columns]

# %%
genres = []
with open('./data/tags-micro-genres.json', encoding='utf-8') as f:
    for line in f:
        tag = json.loads(line)
        genres.append(tag)
genres = pd.DataFrame(genres)
genres = genres.rename(columns={'tags':'genres'})
genres
# Out:
#                                                        _id  \
# 0        {'artist': 'Gotye', 'track': 'Somebody That I ...
# 1        {'artist': 'Lana Del Rey', 'track': 'Blue Jeans'}
# 2             {'artist': 'The xx', 'track': 'Crystalised'}
# 3         {'artist': 'Adele', 'track': 'Someone Like You'}
# 4        {'artist': 'Nirvana', 'track': 'Smells Like Te...
# ...                                                    ...
# 1638463  {'artist': 'Zs', 'track': 'Except When You Don...
# 1638464             {'artist': 'Oval', 'track': '70 kino'}
# 1638465  {'artist': 'Ella Fitzgerald', 'track': 'Make L...
# 1638466  {'artist': 'Shifted Phases', 'track': 'Scatter...
# 1638467  {'artist': 'Alan Parsons Project', 'track': 'E...
#
#                                                     genres         i
# 0        {'pop': 19, 'indie pop': 10, 'rock': 5, 'singe...  36346257
# 1        {'pop': 82, 'soul': 55, 'indie pop': 29, 'cham...   7247506
# 2        {'indie rock': 44, 'rock': 9, 'post-punk': 8, ...  10540381
# 3        {'soul': 88, 'pop': 28, 'singer-songwriter': 7...  36367985
# 4        {'grunge': 100, 'rock': 69, 'alternative rock'...  36039983
# ...                                                    ...       ...
# 1638463                                      {'jazz': 100}  14374397
# 1638464                              {'experimental': 100}   3022988
# 1638465                    {'jazz': 100, 'vocal jazz': 50}  25494731
# 1638466  {'electroclash': 100, 'electro': 100, 'techno'...  34506959
# 1638467  {'progressive rock': 97, 'classic rock': 71, '...  14456757
#
# [1638468 rows x 3 columns]

# %%
uris = pd.read_csv('./data/spotify-uris.tsv', sep='\t')
uris
# Out:
#          track_id                     uri
# 0        36346257  4wCmqSrbyCgxEXROQE6vtV
# 1        32496162  4G8gkOterJn0Ywt6uhqbhp
# 2        33619193  1c8gk2PeTE04A1pIDH9YMk
# 3        32083560  7w87IxuO7BDcJ3YUqCyMTT
# 4        45222862  6mFkJmJqdDVQ1REhVfGgd1
# ...           ...                     ...
# 2378107  25969718  7nzq9ostb7WLVKWaDw6PXn
# 2378108  25970443  149o3oF6f81e7YIJdhJrQa
# 2378109  25971777  5ysnVwfWfzvgX8oHIwJZ35
# 2378110  25974942  4TfMU0JTZ2yzIf3asfRIEA
# 2378111  25978290  745pFPwdbLDEDApFh2UnHu
#
# [2378112 rows x 2 columns]

# %% [markdown]
# ### 10명 이상의 user가 들은 track

# %%
df = listening_count[listening_count['n_user']>=10]
df = df.sort_values('n_user', ascending=False)
df = df.reset_index()
df
# Out:
#          track_id  n_user  total_listening
# 0        36346257   28668           284021
# 1        36039983   27831           206156
# 2        33619193   25813           223400
# 3         9793081   24913           177047
# 4        32083560   23422           211291
# ...           ...     ...              ...
# 5218900  40647538      10               25
# 5218901  24909644      10               23
# 5218902  35268767      10               23
# 5218903  24909861      10               33
# 5218904   6602363      10               79
#
# [5218905 rows x 3 columns]

# %%
df = pd.merge(df, tracks, how='left',on='track_id')
df = pd.merge(df, tags[['i','tags']], how='left', left_on='track_id', right_on='i').drop(columns='i')
df = pd.merge(df, genres[['i','genres']], how='left', left_on='track_id', right_on='i').drop(columns='i')
df = pd.merge(df, uris, how='left',on='track_id')
df
# Out:
#          track_id  n_user  total_listening                    artist_name  \
# 0        36346257   28668           284021                          Gotye
# 1        36039983   27831           206156                        Nirvana
# 2        33619193   25813           223400                          Adele
# 3         9793081   24913           177047                        Nirvana
# 4        32083560   23422           211291              Foster the People
# ...           ...     ...              ...                            ...
# 5218900  40647538      10               25                       Nevertel
# 5218901  24909644      10               23                     John Mayer
# 5218902  35268767      10               23          Northeast Party House
# 5218903  24909861      10               33                Love of Lesbian
# 5218904   6602363      10               79  Seven Lions feat. Shaz Sparks
#
#                                         track_name  \
# 0                     Somebody That I Used to Know
# 1                          Smells Like Teen Spirit
# 2                              Rolling in the Deep
# 3                                  Come as You Are
# 4                                  Pumped Up Kicks
# ...                                            ...
# 5218900                                  The Story
# 5218901  Love Song For No One (Live In Birmingham)
# 5218902                                 Shelf Life
# 5218903                        Love Song Nº 79.899
# 5218904                Below Us (Smooth's DnB Mix)
#
#                                                       tags  \
# 0        {'indie': 100, 'alternative': 79, 'electronic'...
# 1        {'Grunge': 100, 'rock': 69, 'Nirvana': 43, '90...
# 2        {'soul': 100, 'Adele': 95, 'female vocalists':...
# 3        {'Grunge': 100, 'rock': 63, 'Nirvana': 45, '90...
# 4        {'indie': 100, 'indie pop': 69, 'catchy': 38, ...
# ...                                                    ...
# 5218900                                                NaN
# 5218901                                                NaN
# 5218902                                                NaN
# 5218903                                                NaN
# 5218904                  {'Drum n Bass': 100, '2012': 100}
#
#                                                     genres  \
# 0        {'pop': 19, 'indie pop': 10, 'rock': 5, 'singe...
# 1        {'grunge': 100, 'rock': 69, 'alternative rock'...
# 2        {'soul': 100, 'pop': 69, 'singer-songwriter': ...
# 3        {'grunge': 100, 'rock': 63, 'alternative rock'...
# 4        {'indie pop': 69, 'pop': 17, 'indie rock': 17,...
# ...                                                    ...
# 5218900                                                NaN
# 5218901                                                NaN
# 5218902                                                NaN
# 5218903                                                NaN
# 5218904                                                NaN
#
#                             uri
# 0        4wCmqSrbyCgxEXROQE6vtV
# 1        5ghIJDpPoe3CfHMGu71E6T
# 2        1c8gk2PeTE04A1pIDH9YMk
# 3        4P5KoWXOxwuobLmHXLMobV
# 4        7w87IxuO7BDcJ3YUqCyMTT
# ...                         ...
# 5218900                     NaN
# 5218901                     NaN
# 5218902                     NaN
# 5218903                     NaN
# 5218904                     NaN
#
# [5218905 rows x 8 columns]

# %%
print('tags :', df['tags'].isnull().sum())
print('genres :', df['genres'].isnull().sum())
print('uri :', df['uri'].isnull().sum())
# Out:
# tags : 3138011
# genres : 3668038
# uri : 2990028

# %%
df[df.isnull().any(axis=1)]
# Out:
#          track_id  n_user  total_listening                    artist_name  \
# 77       44249371   16347           118629                        Rihanna
# 88       12494556   15928           103455                        Journey
# 100      12496203   15468           100349                          Queen
# 113      45985119   14977           100901         Florence + the Machine
# 144       8457633   14372            97662          Red Hot Chili Peppers
# ...           ...     ...              ...                            ...
# 5218900  40647538      10               25                       Nevertel
# 5218901  24909644      10               23                     John Mayer
# 5218902  35268767      10               23          Northeast Party House
# 5218903  24909861      10               33                Love of Lesbian
# 5218904   6602363      10               79  Seven Lions feat. Shaz Sparks
#
#                                         track_name  \
# 77             We Found Love (feat. Calvin Harris)
# 88                            Don't Stop Believin'
# 100                              Don't Stop Me Now
# 113                            You've Got the Love
# 144                                     Can't Stop
# ...                                            ...
# 5218900                                  The Story
# 5218901  Love Song For No One (Live In Birmingham)
# 5218902                                 Shelf Life
# 5218903                        Love Song Nº 79.899
# 5218904                Below Us (Smooth's DnB Mix)
#
#                                                       tags  \
# 77       {'pop': 100, 'dance': 98, 'Rihanna': 67, 'fema...
# 88       {'classic rock': 100, '80s': 95, 'rock': 65, '...
# 100      {'classic rock': 100, 'rock': 85, 'Queen': 70,...
# 113      {'indie': 100, 'female vocalists': 84, 'altern...
# 144      {'rock': 100, 'alternative rock': 64, 'funk': ...
# ...                                                    ...
# 5218900                                                NaN
# 5218901                                                NaN
# 5218902                                                NaN
# 5218903                                                NaN
# 5218904                  {'Drum n Bass': 100, '2012': 100}
#
#                                                     genres  uri
# 77       {'pop': 100, 'electropop': 10, 'house': 10, 'd...  NaN
# 88       {'classic rock': 100, 'rock': 65, 'pop': 9, 'h...  NaN
# 100      {'classic rock': 100, 'rock': 85, 'glam rock':...  NaN
# 113      {'indie pop': 24, 'pop': 16, 'soul': 11, 'rock...  NaN
# 144      {'rock': 100, 'alternative rock': 64, 'funk': ...  NaN
# ...                                                    ...  ...
# 5218900                                                NaN  NaN
# 5218901                                                NaN  NaN
# 5218902                                                NaN  NaN
# 5218903                                                NaN  NaN
# 5218904                                                NaN  NaN
#
# [4201920 rows x 8 columns]

# %% [markdown]
# ### 100명 이상의 user가 들은 track

# %%
df = listening_count[listening_count['n_user']>=100]
df = df.sort_values('n_user', ascending=False)
df = df.reset_index()
df
# Out:
#         track_id  n_user  total_listening
# 0       36346257   28668           284021
# 1       36039983   27831           206156
# 2       33619193   25813           223400
# 3        9793081   24913           177047
# 4       32083560   23422           211291
# ...          ...     ...              ...
# 767298  16219724     100              263
# 767299  43955450     100              453
# 767300  21701604     100              247
# 767301  19022635     100              403
# 767302  21797921     100              586
#
# [767303 rows x 3 columns]

# %%
df = pd.merge(df, tracks, how='left',on='track_id')
df = pd.merge(df, tags[['i','tags']], how='left', left_on='track_id', right_on='i').drop(columns='i')
df = pd.merge(df, genres[['i','genres']], how='left', left_on='track_id', right_on='i').drop(columns='i')
df = pd.merge(df, uris, how='left',on='track_id')
df
# Out:
#         track_id  n_user  total_listening           artist_name  \
# 0       36346257   28668           284021                 Gotye
# 1       36039983   27831           206156               Nirvana
# 2       33619193   25813           223400                 Adele
# 3        9793081   24913           177047               Nirvana
# 4       32083560   23422           211291     Foster the People
# ...          ...     ...              ...                   ...
# 767298  16219724     100              263         Nocte Obducta
# 767299  43955450     100              453          Kate Micucci
# 767300  21701604     100              247  Emanuel and the Fear
# 767301  19022635     100              403      Tapping the Vein
# 767302  21797921     100              586          Jukka Takalo
#
#                           track_name  \
# 0       Somebody That I Used to Know
# 1            Smells Like Teen Spirit
# 2                Rolling in the Deep
# 3                    Come as You Are
# 4                    Pumped Up Kicks
# ...                              ...
# 767298               Galgendämmerung
# 767299        Walking in Los Angeles
# 767300                  Jimme's Song
# 767301                     Hurricane
# 767302        Jokainen on vähän homo
#
#                                                      tags  \
# 0       {'indie': 100, 'alternative': 79, 'electronic'...
# 1       {'Grunge': 100, 'rock': 69, 'Nirvana': 43, '90...
# 2       {'soul': 100, 'Adele': 95, 'female vocalists':...
# 3       {'Grunge': 100, 'rock': 63, 'Nirvana': 45, '90...
# 4       {'indie': 100, 'indie pop': 69, 'catchy': 38, ...
# ...                                                   ...
# 767298  {'black metal': 100, 'Avant-garde Metal': 72, ...
# 767299  {'acoustic': 100, 'metallica': 50, 'Lo-Fi': 25...
# 767300   {'leapsandloved': 100, 'leapsandloved2010': 100}
# 767301  {'Gothic female': 100, 'industrial': 50, 'Goth...
# 767302                                                NaN
#
#                                                    genres  \
# 0       {'pop': 19, 'indie pop': 10, 'rock': 5, 'singe...
# 1       {'grunge': 100, 'rock': 69, 'alternative rock'...
# 2       {'soul': 100, 'pop': 69, 'singer-songwriter': ...
# 3       {'grunge': 100, 'rock': 63, 'alternative rock'...
# 4       {'indie pop': 69, 'pop': 17, 'indie rock': 17,...
# ...                                                   ...
# 767298  {'black metal': 100, 'avant-garde metal': 72, ...
# 767299                   {'lo-fi': 25, 'death metal': 25}
# 767300                                                NaN
# 767301  {'industrial': 50, 'gothic rock': 50, 'rock': ...
# 767302                                                NaN
#
#                            uri
# 0       4wCmqSrbyCgxEXROQE6vtV
# 1       5ghIJDpPoe3CfHMGu71E6T
# 2       1c8gk2PeTE04A1pIDH9YMk
# 3       4P5KoWXOxwuobLmHXLMobV
# 4       7w87IxuO7BDcJ3YUqCyMTT
# ...                        ...
# 767298                     NaN
# 767299  6cj13nm6MooCRpv42aqbCt
# 767300  2p4gyNFw9GtlM1xKoqafN2
# 767301  5iYXpDu0k2isDpxYZSvCXQ
# 767302  7b0qvg610YRnFZKF72I6oQ
#
# [767303 rows x 8 columns]

# %%
print('tags :', df['tags'].isnull().sum())
print('genres :', df['genres'].isnull().sum())
print('uri :', df['uri'].isnull().sum())
# Out:
# tags : 138481
# genres : 214074
# uri : 122559

# %%
df[df.isnull().any(axis=1)]
# Out:
#         track_id  n_user  total_listening  \
# 77      44249371   16347           118629
# 88      12494556   15928           103455
# 100     12496203   15468           100349
# 113     45985119   14977           100901
# 144      8457633   14372            97662
# ...          ...     ...              ...
# 767295  11110719     100              387
# 767297  14473820     100              318
# 767298  16219724     100              263
# 767300  21701604     100              247
# 767302  21797921     100              586
#
#                                 artist_name  \
# 77                                  Rihanna
# 88                                  Journey
# 100                                   Queen
# 113                  Florence + the Machine
# 144                   Red Hot Chili Peppers
# ...                                     ...
# 767295  I Love You But I've Chosen Darkness
# 767297                                 Zeke
# 767298                        Nocte Obducta
# 767300                 Emanuel and the Fear
# 767302                         Jukka Takalo
#
#                                  track_name  \
# 77      We Found Love (feat. Calvin Harris)
# 88                     Don't Stop Believin'
# 100                       Don't Stop Me Now
# 113                     You've Got the Love
# 144                              Can't Stop
# ...                                     ...
# 767295                                 Dash
# 767297                        Eyes of Satan
# 767298                      Galgendämmerung
# 767300                         Jimme's Song
# 767302               Jokainen on vähän homo
#
#                                                      tags  \
# 77      {'pop': 100, 'dance': 98, 'Rihanna': 67, 'fema...
# 88      {'classic rock': 100, '80s': 95, 'rock': 65, '...
# 100     {'classic rock': 100, 'rock': 85, 'Queen': 70,...
# 113     {'indie': 100, 'female vocalists': 84, 'altern...
# 144     {'rock': 100, 'alternative rock': 64, 'funk': ...
# ...                                                   ...
# 767295                                 {'post-punk': 100}
# 767297  {'punk': 100, 'hardcore': 100, 'hardcore punk'...
# 767298  {'black metal': 100, 'Avant-garde Metal': 72, ...
# 767300   {'leapsandloved': 100, 'leapsandloved2010': 100}
# 767302                                                NaN
#
#                                                    genres  \
# 77      {'pop': 100, 'electropop': 10, 'house': 10, 'd...
# 88      {'classic rock': 100, 'rock': 65, 'pop': 9, 'h...
# 100     {'classic rock': 100, 'rock': 85, 'glam rock':...
# 113     {'indie pop': 24, 'pop': 16, 'soul': 11, 'rock...
# 144     {'rock': 100, 'alternative rock': 64, 'funk': ...
# ...                                                   ...
# 767295                                 {'post-punk': 100}
# 767297  {'punk': 100, 'hardcore': 100, 'hardcore punk'...
# 767298  {'black metal': 100, 'avant-garde metal': 72, ...
# 767300                                                NaN
# 767302                                                NaN
#
#                            uri
# 77                         NaN
# 88                         NaN
# 100                        NaN
# 113                        NaN
# 144                        NaN
# ...                        ...
# 767295                     NaN
# 767297                     NaN
# 767298                     NaN
# 767300  2p4gyNFw9GtlM1xKoqafN2
# 767302  7b0qvg610YRnFZKF72I6oQ
#
# [292327 rows x 8 columns]
